# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\Dell\Desktop\Data Analyst\Spotify_Youtube Dataset.csv')

# %%
data
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
data.drop(['Unnamed: 0', 'Url_spotify', 'Url_youtube'] , axis=1, inplace=True)

# %%
data
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  \
# 0                                         Demon Days      album
# ...

# %%
data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
data['Likes'] = data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)

# %%
data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Title               470
# Channel             470
# Views               470
# Likes                 0
# Comments              0
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Uri                 0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19298 entries, 0 to 20717
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            19298 non-null  object
#  1   Track             19298 non-null  object
#  2   Album             19298 non-null  object
#  3   Album_type        19298 non-null  object
#  4   Uri               19298 non-null  object
#  5   Danceability      19298 non-null  float64
#  6   Energy            19298 non-null  float64
#  7   Key               19298 non-null  float64
#  8   Loudness          19298 non-null  float64
#  9   Speechiness       19298 non-null  float64
#  10  Acousticness      19298 non-null  float64
#  11  Instrumentalness  19298 non-null  float64
#  12  Liveness          19298 non-null  float64
#  13  Valence           19298 non-null  float64
#  14  Tempo             19298 non-null  float64
#  15  Duration_ms       19298 non-null  float64
# ...

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    Speechiness  ...  Duration_ms  \
# 0       0.1770  ...     222640.0
# 1       0.0302  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
# ...

# %%
data.groupby('Artist')['Views'].sum().sort_values(ascending = False)
# Out:
# Artist
# Ed Sheeran          1.546021e+10
# CoComelon           1.460167e+10
# Katy Perry          1.312063e+10
# Charlie Puth        1.216759e+10
# Luis Fonsi          1.162811e+10
#                         ...
# Teufelskicker       3.802800e+04
# Brooks & Dunn       3.324600e+04
# Thomas Karallus     2.519000e+04
# Bibi Blocksberg     2.402000e+04
# Simone & Simaria    8.375000e+03
# Name: Views, Length: 2040, dtype: float64

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    Speechiness  ...  Duration_ms  \
# 0       0.1770  ...     222640.0
# 1       0.0302  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
# ...

# %%
x = data[['Track' , 'Stream']]
x
# Out:
#                                                Track        Stream
# 0                                     Feel Good Inc.  1.040235e+09
# 1                                    Rhinestone Eyes  3.100837e+08
# 2      New Gold (feat. Tame Impala and Bootie Brown)  6.306347e+07
# 3                                 On Melancholy Hill  4.346636e+08
# 4                                     Clint Eastwood  6.172597e+08
# ...                                              ...           ...
# 20713                           JUST DANCE HARDSTYLE  9.227144e+06
# 20714                 SET FIRE TO THE RAIN HARDSTYLE  1.089818e+07
# 20715                      OUTSIDE HARDSTYLE SPED UP  6.226110e+06
# 20716                            ONLY GIRL HARDSTYLE  6.873961e+06
# 20717                             MISS YOU HARDSTYLE  5.695584e+06
#
# [19298 rows x 2 columns]

# %%
x.sort_values('Stream' , ascending = False).head(10)
# Out:
#                                                Track        Stream
# 15250                                Blinding Lights  3.386520e+09
# 12452                                   Shape of You  3.362005e+09
# 19186                              Someone You Loved  2.634013e+09
# 17937                     rockstar (feat. 21 Savage)  2.594927e+09
# 17445  Sunflower - Spider-Man: Into the Spider-Verse  2.538330e+09
# 17938  Sunflower - Spider-Man: Into the Spider-Verse  2.538330e+09
# 13503                                      One Dance  2.522432e+09
# 16099                                         Closer  2.456205e+09
# 16028                                         Closer  2.456205e+09
# 14030                                       Believer  2.369272e+09

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    Speechiness  ...  Duration_ms  \
# 0       0.1770  ...     222640.0
# 1       0.0302  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
# ...

# %%
data.groupby('Track')['Stream'].value_counts().sort_values(ascending = True).head(5)
# Out:
# Track                  Stream
# Love On The Brain      1.036636e+09    1
# Poovoma Oorgolam       3.371093e+06    1
# Poovukkul              1.603454e+07    1
# Pop                    4.613608e+07    1
# Pop Boy (feat. Aitch)  3.044838e+07    1
# Name: count, dtype: int64

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
data.Album_type.unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
album_type = data['Album_type'].value_counts()
album_type
# Out:
# Album_type
# album          13952
# single          4653
# compilation      693
# Name: count, dtype: int64

# %%
data.groupby('Album_type')['Track'].value_counts()
# Out:
# Album_type  Track
# album       Angel                          7
#             Y, ¿Si Fuera Ella? - + Es +    7
#             Hurricane                      6
#             Nada                           6
#             Alone                          5
#                                           ..
# single      私は最強                           1
#             花占い                            1
#             裸の勇者                           1
#             踊り子                            1
#             그대라는 시                         1
# Name: count, Length: 16956, dtype: int64

# %%
plt.pie( album_type , labels = album_type.index , autopct = '%1.1g%%', startangle = 60 , colors = 'rbg' ,
         shadows'True' , explode  = (0.5 , 0.5, 0.5) , pctdistance = 0.5)

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    Speechiness  ...  Duration_ms  \
# 0       0.1770  ...     222640.0
# 1       0.0302  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
# ...

# %%
data_set = data.groupby('Album_type')[['Likes' , 'Views' , 'Comments']].mean()

# %%
data_set
# Out:
#                      Likes         Views      Comments
# Album_type
# album        672593.609948  1.014359e+08  29032.951548
# compilation  544275.818182  8.500535e+07  18074.903319
# single       722266.303890  8.480843e+07  27313.048571

# %%
data_set = data_set.reset_index()

# %%
type(data_set)
# Out:
# pandas.core.frame.DataFrame

# %%
data_set1 = pd.melt(data_set, id_vars = 'Album_type', var_name = 'Attribiute', value_name = 'Total')

# %%
data_set1
# Out:
#     Album_type Attribiute         Total
# 0        album      Likes  6.725936e+05
# 1  compilation      Likes  5.442758e+05
# 2       single      Likes  7.222663e+05
# 3        album      Views  1.014359e+08
# 4  compilation      Views  8.500535e+07
# 5       single      Views  8.480843e+07
# 6        album   Comments  2.903295e+04
# 7  compilation   Comments  1.807490e+04
# 8       single   Comments  2.731305e+04

# %%
plt.figure(figsize = (9,7))
sns.barplot(x = 'Album_type' , y = 'Total' , hue = 'Attribiute', data = data_set1);

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
channel_views = data.groupby('Channel')['Views'].value_counts().sort_values(ascending = False).head(5)

# %%
channel_views
# Out:
# Channel               Views
# Macklemore            1.012206e+09    10
# Jowell & Randy        8.266725e+06    10
# EUROPA Hörspiele      6.639000e+03    10
# JoanJettVEVO          9.870131e+07    10
# HueyLewisTheNewsVEVO  1.309968e+07    10
# Name: count, dtype: int64

# %%
channel_views = channel_views.reset_index()

# %%
type(channel_views)
# Out:
# pandas.core.frame.DataFrame

# %%
channel_views
# Out:
#                 Channel         Views  count
# 0            Macklemore  1.012206e+09     10
# 1        Jowell & Randy  8.266725e+06     10
# 2      EUROPA Hörspiele  6.639000e+03     10
# 3          JoanJettVEVO  9.870131e+07     10
# 4  HueyLewisTheNewsVEVO  1.309968e+07     10

# %%
sns.barplot(x = 'Views' , y = 'Channel' , data = channel_views);

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
data.sort_values(by = 'Views' , ascending = False).head(1)
# Out:
#           Artist      Track Album Album_type  \
# 1147  Luis Fonsi  Despacito  VIDA      album
#
#                                        Uri  Danceability  Energy  Key  \
# 1147  spotify:track:6habFhsOp2NvshLv26DqMb         0.655   0.797  2.0
#
#       Loudness  Speechiness  ...  Duration_ms  \
# 1147    -4.787        0.153  ...     229360.0
#
#                                         Title        Channel         Views  \
# 1147  Luis Fonsi - Despacito ft. Daddy Yankee  LuisFonsiVEVO  8.079649e+09
#
#            Likes   Comments  \
# 1147  50788652.0  4252791.0
#
#                                             Description Licensed  \
# 1147  “Despacito” disponible ya en todas las platafo...     True
#
#       official_video        Stream
# 1147            True  1.506598e+09
#
# [1 rows x 25 columns]

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
track_lv = data[[ 'Track' , 'Likes' , 'Views']]

# %%
track_lv
# Out:
#                                                Track      Likes        Views
# 0                                     Feel Good Inc.  6220896.0  693555221.0
# 1                                    Rhinestone Eyes  1079128.0   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)   282142.0    8435055.0
# 3                                 On Melancholy Hill  1788577.0  211754952.0
# 4                                     Clint Eastwood  6197318.0  618480958.0
# ...                                              ...        ...          ...
# 20713                           JUST DANCE HARDSTYLE     1113.0      71678.0
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     2019.0     164741.0
# 20715                      OUTSIDE HARDSTYLE SPED UP      329.0      35646.0
# 20716                            ONLY GIRL HARDSTYLE       88.0       6533.0
# 20717                             MISS YOU HARDSTYLE     2484.0     158697.0
#
# [19298 rows x 3 columns]

# %%
track_lv['LikesVies_ratio'] = data['Likes']/data['Views']*100
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4432\4217004135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   track_lv['LikesVies_ratio'] = data['Likes']/data['Views']*100

# %%
track_lv
# Out:
#                                                Track      Likes        Views  \
# 0                                     Feel Good Inc.  6220896.0  693555221.0
# 1                                    Rhinestone Eyes  1079128.0   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)   282142.0    8435055.0
# 3                                 On Melancholy Hill  1788577.0  211754952.0
# 4                                     Clint Eastwood  6197318.0  618480958.0
# ...                                              ...        ...          ...
# 20713                           JUST DANCE HARDSTYLE     1113.0      71678.0
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     2019.0     164741.0
# 20715                      OUTSIDE HARDSTYLE SPED UP      329.0      35646.0
# 20716                            ONLY GIRL HARDSTYLE       88.0       6533.0
# 20717                             MISS YOU HARDSTYLE     2484.0     158697.0
#
#        LikesVies_ratio
# ...

# %%
track_lv.sort_values(by = 'LikesVies_ratio' , ascending = False).head(7)
# Out:
#                               Track     Likes      Views  LikesVies_ratio
# 19968                         Intro  237761.0   954081.0        24.920421
# 19969                   Safety Zone  453910.0  1952637.0        23.246000
# 19967                        Future  250116.0  1180522.0        21.186899
# 19971                 Pandora's Box  253702.0  1265231.0        20.051832
# 16297  My Universe - Galantis Remix  371437.0  2067753.0        17.963316
# 15065           Burn It (feat. MAX)  188244.0  1054438.0        17.852543
# 8105         No.2 (with parkjiyoon)  346440.0  2050047.0        16.899125

# %%
track_lv.sort_values(by = 'LikesVies_ratio' , ascending = True).head(3)
# Out:
#                                  Track  Likes       Views  LikesVies_ratio
# 10027  Persona Ideal - Me Tengo Que Ir    0.0  13627867.0              0.0
# 5587                    April In Paris    0.0    216572.0              0.0
# 5500                        Calaverada    0.0     39830.0              0.0

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
Track_Danceability = data.groupby('Album')[ 'Danceability'].sum().sort_values(ascending = False)

# %%
Track_Danceability
# Out:
# Album
# Greatest Hits                                                                              17.356
# Hamilton (Original Broadway Cast Recording)                                                16.610
# HEROES & VILLAINS                                                                          14.300
# RODZINNY BIZNES                                                                            13.491
# An Evening With Silk Sonic                                                                 13.349
#                                                                                             ...
# Israeli Salad                                                                               0.000
# Soothing Brown Noise Waves and Calming Ambient Combinations (Loopable and without Fade)     0.000
# Voyager - Essential Max Richter                                                             0.000
# ...

# %%
data[data['Album'] == 'Greatest Hits']
# Out:
#                                 Artist  \
# 220                               2Pac
# 222                               2Pac
# 225                               2Pac
# 268                      Fleetwood Mac
# 1232                 Bruce Springsteen
# 1236                 Bruce Springsteen
# 1862                      Shania Twain
# 2164                       Wyclef Jean
# 3079                     Tracy Chapman
# 3097                           Blondie
# 3147                      Willie Colón
# 3578                        Eurythmics
# 3579                        Eurythmics
# 3580                        Eurythmics
# 3598                       Snow Patrol
# 3836                      James Taylor
# 3842                      James Taylor
# 4324   Tom Petty and the Heartbreakers
# 5185                    Gloria Estefan
# 6721                           Kenny G
# 8434                      Annie Lennox
# 8435                      Annie Lennox
# 9635                      Foo Fighters
# ...

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    Speechiness  ...  Duration_ms                                       Title  \
# 0        0.177  ...     222640.0  Gorillaz - Feel Good Inc. (Official Video)
#
#     Channel        Views      Likes  Comments  \
# 0  Gorillaz  693555221.0  6220896.0  169907.0
#
#                                          Description Licensed  official_video  \
# 0  Official HD Video for Gorillaz' fantastic trac...     True            True
#
#          Stream
# 0  1.040235e+09
#
# [1 rows x 25 columns]

# %%
lvc = data[['Likes', 'Views' , 'Comments']]

# %%
lvc
# Out:
#            Likes        Views  Comments
# 0      6220896.0  693555221.0  169907.0
# 1      1079128.0   72011645.0   31003.0
# 2       282142.0    8435055.0    7399.0
# 3      1788577.0  211754952.0   55229.0
# 4      6197318.0  618480958.0  155930.0
# ...          ...          ...       ...
# 20713     1113.0      71678.0       0.0
# 20714     2019.0     164741.0       0.0
# 20715      329.0      35646.0       0.0
# 20716       88.0       6533.0       0.0
# 20717     2484.0     158697.0       0.0
#
# [19298 rows x 3 columns]

# %%
lvc.corr()
# Out:
#              Likes     Views  Comments
# Likes     1.000000  0.891695  0.631035
# Views     0.891695  1.000000  0.431077
# Comments  0.631035  0.431077  1.000000

# %%
sns.heatmap(lvc.corr());
